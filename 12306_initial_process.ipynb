# %%
from IPython.display import clear_output
import pinyin
import operator
import re
import random
import time


workspace = "/Users/liyue/research/DATA/12306/"
def lcs(a, b):
    lengths = [[0 for j in range(len(b)+1)] for i in range(len(a)+1)]
    # row 0 and column 0 are initialized to 0 already
    for i, x in enumerate(a):
        for j, y in enumerate(b):
            if x == y:
                lengths[i+1][j+1] = lengths[i][j] + 1
            else:
                lengths[i+1][j+1] = \
                    max(lengths[i+1][j], lengths[i][j+1])
    # read the substring out from the matrix
    result = ""
    x, y = len(a), len(b)
    while x != 0 and y != 0:
        if lengths[x][y] == lengths[x-1][y]:
            x -= 1
        elif lengths[x][y] == lengths[x][y-1]:
            y -= 1
        else:
            assert a[x-1] == b[y-1]
            result = a[x-1] + result
            x -= 1
            y -= 1
    return result

def lccs(S,T): 
    m = len(S) 
    n = len(T) 
    counter = [[0]*(n+1) for x in range(m+1)] 
    longest = 0 
    lcs_set = set() 
    for i in range(m): 
        for j in range(n): 
            if S[i] == T[j]: 
                c = counter[i][j] + 1 
                counter[i+1][j+1] = c 
                if c > longest: 
                    lcs_set = set() 
                    longest = c 
                    lcs_set.add(S[i-c+1:i+1]) 
                elif c == longest: 
                    lcs_set.add(S[i-c+1:i+1]) 
    if len(lcs_set) > 0:
        return lcs_set.pop()
    else:
        return ""

def adaptseg(pwd):
    lowerc = "abcdefghijklmnopqrstuvwxyz"
    upperc = lowerc.upper()
    number = "1234567890"
    out = ""
    for i in range(0,len(pwd)):
        if pwd[i] in lowerc or pwd[i] in upperc:
            out += "L"
        elif pwd[i] in number:
            out += "D"
        else:
            out += "S"
    return out
    
def seg(pwd):
    lowerc = "abcdefghijklmnopqrstuvwxyz"
    upperc = lowerc.upper()
    number = "1234567890"
    out = ""
    lastchar = ""
    counter = 0
    segdic = {}
    for i in range(0,len(pwd)):
        '''
        if eachchar in lowerc:
            if lastchar != "L":
                out += str(counter)
                out += "L"
                counter = 1
            else:
                counter +=1
            lastchar = "L"
        elif eachchar in upperc:
            if lastchar != "U":
                out += str(counter)
                out += "U"
                counter = 1
            else:
                counter += 1
            lastchar = "U"
        '''
        if pwd[i] in lowerc or pwd[i] in upperc:
            if lastchar != "L":
                dicentry = lastchar + str(counter)
                if dicentry in segdic:
                    segdic[dicentry].append(pwd[i-counter:i])
                else:
                    segdic[dicentry] = [pwd[i-counter:i]]
                out += str(counter)
                out += "L"
                counter = 1
            else:
                counter += 1
            lastchar = "L"
        elif pwd[i] in number:
            if lastchar != "D":
                dicentry = lastchar + str(counter)
                if dicentry in segdic:
                    segdic[dicentry].append(pwd[i-counter:i])
                else:
                    segdic[dicentry] = [pwd[i-counter:i]]
                out += str(counter)
                out += "D"
                counter = 1
            else:
                counter += 1
            lastchar = "D"
        else:
            if lastchar != "S":
                dicentry = lastchar + str(counter)
                if dicentry in segdic:
                    segdic[dicentry].append(pwd[i-counter:i])
                else:
                    segdic[dicentry] = [pwd[i-counter:i]]
                out += str(counter)
                out += "S"
                counter = 1
            else:
                counter += 1
            lastchar = "S"
    dicentry = lastchar + str(counter)
    if dicentry in segdic:
        segdic[dicentry].append(pwd[i-counter+1:i+1])
    else:
        segdic[dicentry] = [pwd[i-counter+1:i+1]]
    segdic.pop("0")
    out += str(counter)
    return (out[1:],segdic)

def distri(mylist,m):
    disdict = {}
    for each in mylist:
        if each[m] in disdict:
            disdict[each[m]] += 1
        else:
            disdict[each[m]] = 1
    sorted_x = sorted(disdict.items(), key=operator.itemgetter(1))
    result = []
    for i in range(len(sorted_x)-1, len(sorted_x)-21,-1):
        result.append([sorted_x[i][0],sorted_x[i][1]/float(len(mylist))])
    return result

def greatest(mylist):
    c = 0
    st = ""
    for each in mylist:
        if len(each) > c:
            c = len(each)
            st = each
    return st

def cvg(mylist,thre): #(LISTNAME, PWD, REF, REFLEN, THRESHOLD)
    pwd = mylist[0]
    bd = mylist[1]
    name = mylist[2]
    email = mylist[3]
    cell = mylist[4]
    acctn = mylist[5]
    IDN = mylist[6]
    struct = mylist[7]
    structdic = mylist[8]
    cvg = ""
    for eachstruct in structdic:
        if "L" in eachstruct:
            for item in structdic[eachstruct]:
                x = lcs(item,name)
                y = lcs(item,email)
                z = lcs(item,acctn)
                gg = greatest([x,y,z])
                if float(len(gg))/len(item) >= thre:
                    cvg += gg
        if "D" in eachstruct:
            for item in structdic[eachstruct]:
                x = lcs(item,bd)
                y = lcs(item,email)
                z = lcs(item,cell)
                a = lcs(item,IDN)
                b = lcs(item,acctn)
                gg = greatest([x,y,z,a,b])
                if float(len(gg))/len(item) >= thre:
                    cvg += gg
    return cvg

def cvgmatch(infolist,seg):
    pwd = infolist[0]
    bd = infolist[1]
    name = infolist[-1]
    email = infolist[3]
    cell = infolist[4]
    acctn = infolist[5]
    IDN = infolist[6]
    match = False
    fullname = pinyin.get(name)
    ininame = pinyin.get_initial(name).replace(" ","")
    for each in (fullname,ininame):
        if seg in each:
            match = True
    if seg in bd or seg in email or seg in cell or seg in acctn or seg in IDN:
        match = True
    return match
    
def newcvg(infolist,windowsize):
    pwd = infolist[0].lower()
    matchtag = [0] * len(pwd)
    if len(pwd) < windowsize:
        return 0
    else:
        for i in range(0,len(pwd)-windowsize+1):
            stringseg = pwd[i:i+windowsize]
            if cvgmatch(infolist,stringseg):
                for j in range(i,i+windowsize):
                    matchtag[j] = 1
    coverlength = 0.0
    for each in matchtag:
        coverlength += each
    return coverlength/len(pwd)

def dynacvg(infolist):
    windowsize = 2
    pwd = infolist[0].lower()
    tmppwd = pwd
    matchtag = [0] * len(pwd)
    matchmark = 0
    while windowsize <= len(tmppwd):
        stringseg = tmppwd[:windowsize]
        matched = cvgmatch(infolist,stringseg)
        if matched:
            if windowsize != len(tmppwd):#continue match
                windowsize += 1
            else:
                for j in range(matchmark,matchmark+windowsize):#match stops at the end of string
                    matchtag[j] = windowsize
                break
        else:#No match found
            windowsize -= 1
            if windowsize >= 2:
                for j in range(matchmark,matchmark+windowsize):
                    matchtag[j] = windowsize
            matchmark += windowsize
            tmppwd = tmppwd[windowsize:]
            windowsize = 2
    tt = 0
    for each in matchtag:
        tt += each
    return float(tt)/(len(pwd)*len(pwd))

                

def get_all_substrings(input_string):
  length = len(input_string)
  return [input_string[i:j+1] for i in xrange(length) for j in xrange(i,length)]

def matchbd(seg,bd):
    #YYYYMMDD, YYYYMDD, YYYYMD, YYMMDD, YYMDD, YYMD, MMDD, MDD, MD, MMDDYY, MMDDYYYY, DDMMYY, DDMMYYYY,
    if re.search('[a-zA-Z]', seg) == None: #NO STRING
        YYYY = bd[:4]
        YY = bd[2:4]
        MM = bd[4:6]
        M = bd[5]
        DD = bd[6:8]
        D = bd[7]
        trial = [YYYY+MM+DD, YYYY+M+DD, YYYY+M+D, YY+MM+DD, YY+M+DD, YY+M+D, YYYY+MM, YYYY+DD, YYYY, YY, MM+DD, M+DD, M+D,\
                 MM+DD+YY, MM+DD+YYYY, DD+MM+YY, DD+MM+YYYY]
        if seg in trial:
            return 1
    return 0
def matchname(seg,name):
    fullname = pinyin.get(name)
    try:
        lastname = pinyin.get(name[:3])
        lastini = pinyin.get_initial(name[:3]).replace(" ","")
    except:
        try:
            name = name[1:]
            lastname = pinyin.get(name[:3])
            lastini = pinyin.get_initial(name[:3]).replace(" ","")
        except:
            return fullname
    firstname = pinyin.get(name[3:])
    firstini = pinyin.get_initial(name[3:]).replace(" ","")
    ininame = pinyin.get_initial(name).replace(" ","")
    try:
        result = []
        result.append(firstname)
        result.append(lastname)
        result.append(firstini+lastini)
        result.append(firstini+lastname)
        result.append(firstname+lastini)
        result.append(firstname+lastname)
        result.append(fullname)
        result.append(ininame)
        result.append(lastini+firstname)
        result.append(lastname+firstini)
        newresult = list(set(result))
        if seg in newresult:
            return 1
    except:
        return 0
def printname(name):
    fullname = pinyin.get(name)
    try:
        lastname = pinyin.get(name[:3])
        lastini = pinyin.get_initial(name[:3]).replace(" ","")
    except:
        try:
            name = name[1:]
            lastname = pinyin.get(name[:3])
            lastini = pinyin.get_initial(name[:3]).replace(" ","")
        except:
            return fullname
    firstname = pinyin.get(name[3:])
    firstini = pinyin.get_initial(name[3:]).replace(" ","")
    ininame = pinyin.get_initial(name).replace(" ","")
    try:
        result = []
        result.append(firstname)
        result.append(lastname)
        result.append(firstini+lastini)
        result.append(firstini+lastname)
        result.append(firstname+lastini)
        result.append(firstname+lastname)
        result.append(fullname)
        result.append(ininame)
        result.append(lastini+firstname)
        result.append(lastname+firstini)
        newresult = list(set(result))
        out = ""
        for each in newresult:
            out += each+"|"
        return out[:-1]
    except:
        return fullname
        
        
def matchemail(seg,email):
    if seg in email and len(seg)>=4:
        return 1
def matchcell(seg,cell):
    if seg in cell and len(seg)>=4:
        return 1
def matchaccount(seg,acct):
    if seg in acct and len(seg)>=4:
        return 1
def matchID(seg,ID):
    ID1 = ID[:6]
    ID2 = ID[14:]
    if seg in ID1 and len(seg)>=4:
        return 1
    if seg in ID2 and len(seg)>=4:
        return 1


    
def matchsub(mystring,listitem):
    result = mystring.lower()
    newform = ""
    measure = True #true is doing measurement
    bd = listitem[1]
    name = listitem[2]
    email = listitem[3]
    cell = listitem[4]
    account = listitem[5]
    ID = listitem[6]
    name = listitem[-1]
    sub = get_all_substrings(mystring)
    sub.sort(key=len, reverse=True)
    rec = []
    if len(mystring) == 0:
        return ""
    for each in sub:
        tag = ""
        if len(each) >= 2:
            if matchbd(each,bd) == 1:
                rec = result.split(each)
                if measure:
                    tag += "[BD]"
                else:
                    tag = "B"*len(each)
            if matchname(each,name) == 1:
                rec = result.split(each)
                if measure:
                    if tag!="":
                        tag += "&[NAME]"
                    else:
                        tag = "[NAME]"
                else:
                    tag = "N"*len(each)
            if matchaccount(each,account) == 1:
                rec = result.split(each)
                if measure:
                    if tag!="":
                        tag += "&[ACCT]"
                    else:
                        tag = "[ACCT]"
                else:
                    tag = "A"*len(each)
            if matchemail(each,email) == 1:
                rec = result.split(each)
                if measure:
                    if tag!="":
                        tag += "&[EMAIL]"
                    else:
                        tag = "[EMAIL]"
                else:
                    tag = "E"*len(each)
            if matchcell(each,cell) == 1:
                rec = result.split(each)
                if measure:
                    if tag!="":
                        tag += "&[CELL]"
                    else:
                        tag = "[CELL]"
                else:
                    tag = "C"*len(each)
            if matchID(each,ID) == 1:
                rec = result.split(each)
                if measure:
                    if tag!="":
                        tag += "&[ID]"
                    else:
                        tag = "[ID]"
                else:
                    tag = "I"*len(each)
            if tag != "":
                if "&" in tag:
                    tag = " " + tag + " "
                break
        else:
            break
    if len(rec) > 0:
        for i in range (0,len(rec)-1):
            newform += matchsub(rec[i],listitem) + tag
        newform += matchsub(rec[-1],listitem)
    else:#nomatch
        if measure:
            newform = seg(mystring)[0]  #When measurement is needed
            #newform = "\t"+mystring+"\t"
        else:
            newform = adaptseg(mystring) #ADAPT TO PCFG CODE
    return newform
            
def matchpersonal(listitem):
    password = listitem[0]
    return matchsub(password,listitem)
    
    
def disamb(mat,rst):
    rest = []
    if "&" in mat: #furthersplit
        dislist = mat.split()
        pre = ""
        after = ""
        for i in range(0,len(dislist)):
            if "&" in dislist[i]:
                tmp = dislist[i].split("&")
                for j in range(i+1,len(dislist)):
                    after += " " +dislist[j]
                for each in tmp:
                    nxt = pre+each+after
                    disamb(nxt,rst)
                break
            else:
                pre += dislist[i]

    else:
        additem = mat.replace(" ","")
        rst.append(additem)
        
        
def matchpinyin(mystring,ptable):
    result = mystring
    mypinyin = ""
    sub = get_all_substrings(mystring)
    sub.sort(key=len,reverse=True)
    rec = []
    for each in sub:
        if each in ptable:#A Match
            rec = result.split(each)
            tag = each
            break
    if len(rec) > 0:
        for i in range (0,len(rec)-1):
            mypinyin += matchpinyin(rec[i],ptable) + tag + "\t"
        mypinyin += matchpinyin(rec[-1],ptable)
    else:
        mypinyin = ""
    return mypinyin
    
def sortlist(mylist,k):
    mydic = {}
    for each in mylist:
        if each in mydic:
            mydic[each] += 1
        else:
            mydic[each] = 1
    sorted_x = sorted(mydic.items(), key=operator.itemgetter(1))
    outline = ""
    #flog = open("structures.txt","w")
    #for i in range(len(sorted_x)-1,0,-1):
    #    flog.write(str(sorted_x[i][0])+"\t"+"%.30f"%(sorted_x[i][1]/float(len(mylist)))+"\n")
    #flog.close()
    for i in range(len(sorted_x)-1,len(sorted_x)-k-1,-1):
        try:
            outline += str(sorted_x[i][0])+"&"+str(sorted_x[i][1]) + "&"+str(sorted_x[i][1]/float(len(mylist))*100)[:5]+"\%\n"
            #outline += "&" + str(sorted_x[i][0])+"&"+str(sorted_x[i][1]/9856.0*100)[:5]+"\%\n"
        except:
            outline += str(sorted_x[i][0]) + "&"+str(sorted_x[i][1])+"&" +str(sorted_x[i][1]/float(len(mylist))*100)+"\%\n"
    return outline

def addstring(mlist):
    outline = ""
    for i in range(0,len(mlist[0])):
        for each in mlist:
            outline += each[i]
        outline += "\n"
    return outline

# %%
f = open("/Users/liyue/research/DATA/12306/data","r")
lines = f.readlines()
f.close()
segdic = {}
D7 = []
D6 = []
D8 = []
mpwd = []
forpwd = []
for eachline in lines:
    line = eachline.split("----")
    email = line[0]
    pwd = line[1]
    name = pinyin.get(line[2].decode("gbk").encode('utf-8'))
    BD = line[3][6:14]
    IDN = line[3]
    ActN = line[4]
    Tel = line[5]
    myseg = seg(pwd)
    oriname = line[2].decode("gbk").encode('utf-8')
    if len(IDN) == 18:
        mpwd.append([pwd,BD,name,email,Tel,ActN,IDN,myseg[0],myseg[1],oriname])
    else:
        forpwd.append([pwd,BD,name,email,Tel,ActN,IDN,myseg[0],myseg[1],oriname])
    if myseg[0] in segdic:
        segdic[myseg[0]] += 1
    else:
        segdic[myseg[0]] = 1
for each in forpwd:
    print each
# Out:
# ['MMMDQS1234', '218', 'linjunye', '455342798@qq.com', '15659221970', 'aa243452584', 'H60013218', 'L6D4', {'L6': ['MMMDQS'], 'D4': ['1234']}, '\xe6\x9e\x97\xe4\xbf\x8a\xe7\x83\xa8']
# ['5201314', '62300', 'chenlinxin', '295011446@qq.com', '15018709907', 'chanlamhingking', 'H0142562300', 'D7', {'D7': ['5201314']}, '\xe9\x99\x88\xe9\x9c\x96\xe9\x91\xab']
# ['7731341', '75061700', 'chenxingchong', 'tuken@126.com', '15851482248', 'tooken', '440823750617003', 'D7', {'D7': ['7731341']}, '\xe9\x99\x88\xe5\x85\xb4\xe5\x85\x85']
# ['sakura123', '52304', 'lujiarong', 'rxjhshuai@qq.com', '13960838892', 'szgzlye', 'M0200752304', 'L6D3', {'L6': ['sakura'], 'D3': ['123']}, '\xe5\x8d\xa2\xe5\x98\x89\xe8\x8d\xa3']
# ['w618x3', '83301', 'wuqijia', 'wurosy@qq.com', '14714528366', 'wurosy', 'H0416483301', 'L1D3L1D1', {'D1': ['3'], 'D3': ['618'], 'L1': ['w', 'x']}, '\xe5\x90\xb4\xe5\x90\xaf\xe5\x98\x89']
# ['qq86554073', '62032318', 'zhouyin', 'zl88925@sina.com', '13820318884', 'heisedehuali', '120104620323181', 'L2D8', {'L2': ['qq'], 'D8': ['86554073']}, '\xe5\x91\xa8\xe9\x93\xb6']
# ['7981990', '2', 'fuwenchao', 'wenchao3732@sina.com', '18633319453', 'wenchao3732', '0610072', 'D7', {'D7': ['7981990']}, '\xe4\xbb\x98\xe6\x96\x87\xe8\xb6\x85']
# ['gz845hc8', '577', 'qingshuishanbo', 'eva825_yoshi@live.jp', '15921749430', 'eva825_yoshi', 'MZ0463577', 'L2D3L2D1', {'L2': ['gz', 'hc'], 'D3': ['845'], 'D1': ['8']}, '\xe6\xb8\x85\xe6\xb0\xb4\xe5\x96\x84\xe5\x8d\x9a']
# ['00windxs', '51201', 'tanyunfeng', 'instrike@qq.com', '15918760172', 'instrike', 'H0469851201', 'D2L6', {'L6': ['windxs'], 'D2': ['00']}, '\xe8\xb0\xad\xe4\xba\x91\xe5\xb3\xb0']
# ['ty2004vik', '06', u'UDAYA SANKAR', 'ty2004vik@126.com', '15006198805', 'a15006198805', 'K9510706', 'L2D4L3', {'D4': ['2004'], 'L2': ['ty'], 'L3': ['vik']}, 'UDAYA SANKAR']
# ['qc1991613', '665', 'qiuchao', 'qc0801@yahoo.com', '13907340452', 'Qc0801', 'G36303665', 'L2D7', {'L2': ['qc'], 'D7': ['1991613']}, '\xe9\x82\xb1\xe8\xb6\x85']
# ['19880122Gp', '002', 'gaopeng', 'sjyh1988@163.com', '15837190235', 'gaopeng258742220', 'G34063002', 'D8L2', {'L2': ['Gp'], 'D8': ['19880122']}, '\xe9\xab\x98\xe9\xb9\x8f']
# ['zhaoshan29', '1', 'wangbo', 'wbozsaa@126.com', '18686575805', 'wbozsaa', '2202031', 'L8D2', {'D2': ['29'], 'L8': ['zhaoshan']}, '\xe7\x8e\x8b\xe5\x8d\x9a']
# ['100200aa', '76203', 'cailiangshun', '113847656@qq.com', '15021325042', 'c538224310', 'H0388676203', 'D6L2', {'D6': ['100200'], 'L2': ['aa']}, '\xe8\x94\xa1\xe8\x89\xaf\xe9\xa1\xba']
# ['cs1988327', '305', 'chenshuang', 'cs.0327@hotmail.com', '13913928480', 'cs880327', 'G28643305', 'L2D7', {'L2': ['cs'], 'D7': ['1988327']}, '\xe9\x99\x88\xe7\x88\xbd']
# ['950516hao', '54300', 'cengbinghao', '376438415@qq.com', '15985957633', 'qw376438415', 'H1051954300', 'D6L3', {'D6': ['950516'], 'L3': ['hao']}, '\xe6\x9b\xbe\xe7\x82\xb3\xe8\xb1\xaa']
# ['g87665432', '7', 'guoxichao', 'g87665432@126.com', '13324111587', 'gxc87665432', '0574047', 'L1D8', {'D8': ['87665432'], 'L1': ['g']}, '\xe9\x83\xad\xe7\x86\x99\xe8\xb6\x85']
# ['az05462', '27101', 'sunli', 'lanxing_99@163.com', '18638388871', 'henanhexiang', 'H0417727101', 'L2D5', {'D5': ['05462'], 'L2': ['az']}, '\xe5\xad\x99\xe4\xbf\x90']
# ['haoren911', '265', 'chenhang', 'guihunhao2@163.com', '18695604805', 'guihunhao', 'G36848265', 'L6D3', {'L6': ['haoren'], 'D3': ['911']}, '\xe9\x99\x88\xe8\x88\xaa']
# ['a00000', '695', 'cuiwanji', '273384307@qq.com', '13826546256', 'a13826546256', 'G47702695', 'L1D5', {'D5': ['00000'], 'L1': ['a']}, '\xe5\xb4\x94\xe4\xb8\x87\xe5\x90\x89']
# ['ls512424', '198405', 'lishuai', 'lsgled@163.com', '15377599367', 'lsgled', '420606198405', 'L2D6', {'D6': ['512424'], 'L2': ['ls']}, '\xe6\x9d\x8e\xe5\xb8\x85']
# ['wenwen520', '50503', 'zhangyaowen', 'cheungyiuman@163.com', '18608425833', 'z18608425833', 'H0344750503', 'L6D3', {'L6': ['wenwen'], 'D3': ['520']}, '\xe5\xbc\xa0\xe8\x80\x80\xe6\x96\x87']
# ['sishenk801', '191', u'muhetaier\uff0etuersun', 'muhtarjan801@126.com', '13579277924', 'sishenk', '652922191', 'L7D3', {'D3': ['801'], 'L7': ['sishenk']}, '\xe7\xa9\x86\xe5\x90\x88\xe5\xa4\xaa\xe5\xb0\x94\xef\xbc\x8e\xe5\x9b\xbe\xe5\xb0\x94\xe8\x8d\xaa']
# ['gogo0093', '693', u'OKUSA RIKIO', 'r0093@hotmail.com', '18622119630', 'okusarikio', 'TZ0630693', 'L4D4', {'L4': ['gogo'], 'D4': ['0093']}, 'OKUSA RIKIO']
# ['byq123456', '043', u'Kan Ni', 'kan0408@qq.com', '18868790883', 'nikantime', '421099043', 'L3D6', {'D6': ['123456'], 'L3': ['byq']}, 'Kan Ni']
# ['zmy118008', '123', u'zhouXX', 'zmytyg@sina.com', '15212321313', 'zmyyq927', '123123123', 'L3D6', {'D6': ['118008'], 'L3': ['zmy']}, '\xe5\x91\xa8XX']
# ['bc38131415', '215', 'yujie', 'yujie33568146@qq.com', '15716010383', 'bestaj001', 'G20812215', 'L2D8', {'L2': ['bc'], 'D8': ['38131415']}, '\xe5\x96\xbb\xe6\x8d\xb7']
# ['a306377252', '13002', 'zhuozuxian', 'wx121893503@hotmail.com', '13048220308', 'simoncheuk', 'H0449713002', 'L1D9', {'D9': ['306377252'], 'L1': ['a']}, '\xe5\x8d\x93\xe7\xa5\x96\xe8\xb4\xa4']
# ['king1853', '86042500', 'zhaoqiang', 'king-1853@163.com', '15585111158', 'ufo1853', '522121860425003', 'L4D4', {'L4': ['king'], 'D4': ['1853']}, '\xe8\xb5\xb5\xe5\xbc\xba']
# ['asd060801', '8', 'tianyaming', 'asd36991@163.com', '18235398295', 'asd36990', '0410058', 'L3D6', {'D6': ['060801'], 'L3': ['asd']}, '\xe7\x94\xb0\xe4\xba\x9a\xe9\xb8\xa3']
# ['202cat', '2', 'yizhenyu', 'yyboyscat@sohu.com', '13975959551', 'yyboyscat2', 'E073512', 'D3L3', {'D3': ['202'], 'L3': ['cat']}, '\xe6\x98\x93\xe6\x8c\xaf\xe5\xae\x87']
# ['pan8865', '551', u'KHAN IJLAL AHMED', 'panbb126@163.com', '13088694303', 'gz4123551', 'GZ4123551', 'L3D4', {'D4': ['8865'], 'L3': ['pan']}, 'KHAN IJLAL AHMED']
# ['sxd8dc', '22901', 'pengbo', 'aouo@tom.com', '18675827188', 'pangpo1968', 'H0312422901', 'L3D1L2', {'L2': ['dc'], 'L3': ['sxd'], 'D1': ['8']}, '\xe5\xbd\xad\xe6\xb3\xa2']
# ['forme621', '19301', u'LEONG CHI SENG', 'forrest.seng@gmail.com', '13926466302', 'f2forrestsenggmailcom', 'M0035819301', 'L5D3', {'L5': ['forme'], 'D3': ['621']}, 'LEONG CHI SENG']
# ['yu869583', '569', 'yufeng', '357486430@qq.com', '15850653962', 'jackyuhaha', 'G35351569', 'L2D6', {'D6': ['869583'], 'L2': ['yu']}, '\xe4\xbf\x9e\xe5\xb3\xb0']
# ['woaini1314', '54605', 'yingyingyuan', 'dicky930816@hotmail.com', '15022364409', 'd159305300', 'H0343254605', 'L6D4', {'L6': ['woaini'], 'D4': ['1314']}, '\xe8\x8b\xb1\xe9\xa2\x96\xe6\xba\x90']
# ['1q2w3e4r', '029', 'jiangjun', 'chongfusidaye@126.com', '13701082022', 'chongfusdiaye', 'E07113029', 'D1L1D1L1D1L1D1L1', {'L1': ['q', 'w', 'e', 'r'], 'D1': ['1', '2', '3', '4']}, '\xe5\xa7\x9c\xe7\x8f\xba']
# ['kpmg1234', '73', u'QUCHAO', 'davidqu@yahoo.com', '13918661376', 'dtemp1', 'JX568273', 'L4D4', {'L4': ['kpmg'], 'D4': ['1234']}, 'QUCHAO']
# ['m1390102x', '736', 'maxiao', '494042426@qq.com', '15155885696', 'mx12341231', 'G29280736', 'L1D7L1', {'D7': ['1390102'], 'L1': ['m', 'x']}, '\xe9\xa9\xac\xe5\x95\xb8']
# ['26729950', '33', 'xuyuliang', 'kevin@motoknife.com.cn', '18616507113', 'motokevin', '04368333', 'D8', {'D8': ['26729950']}, '\xe8\xa8\xb1\xe8\xa3\x95\xe8\x89\xaf']
# ['fan0524', '22201', 'hufan', 'owowow69@hotmail.com', '18601791717', 'owowow', 'H0051722201', 'L3D4', {'D4': ['0524'], 'L3': ['fan']}, '\xe8\x83\xa1\xe5\x87\xa1']
# ['511511', '6', 'sunshengming', '2668976@qq.com', '15020052511', 'ssm511', '5211566', 'D6', {'D6': ['511511']}, '\xe5\xad\x99\xe6\x99\x9f\xe9\x93\xad']
# ['qq79232166', '208', 'linqianlei', '445360941@qq.com', '18818800945', 'lv18818800945', 'E00351208', 'L2D8', {'L2': ['qq'], 'D8': ['79232166']}, '\xe6\x9e\x97\xe8\x8c\x9c\xe8\x95\xbe']
# ['6813480wxa', '31', 'wangxu', 'wangxu3480@sina.com', '15941023222', 'wangxu42046999', '21120331', 'D7L3', {'L3': ['wxa'], 'D7': ['6813480']}, '\xe7\x8e\x8b\xe6\x97\xad']
# ['nb12345', '49', 'fanbaoren', 'beckygirl_dif@yahoo.com.tw', '13764070818', 'backlover', '08540049', 'L2D5', {'D5': ['12345'], 'L2': ['nb']}, '\xe8\x8c\x83\xe5\xaf\xb6\xe4\xbb\x81']
# ['168168tzw', '85', u'TANZHENWEI', 'aya138@hotmail.com', '18621116286', 'mt19861111', 'M2735285', 'D6L3', {'D6': ['168168'], 'L3': ['tzw']}, 'TANZHENWEI']
# ['hung1977', '19', 'hongzhengyi', 'gm_ethen@yahoo.com', '18665299420', 'ethen6628', '03745619', 'L4D4', {'L4': ['hung'], 'D4': ['1977']}, '\xe6\xb4\xaa\xe6\xad\xa3\xe9\xa2\x90']
# ['a19891122', '28400', 'huangyongjie', '149227795@qq.com', '18607516552', 'a149227795', 'H1040728400', 'L1D8', {'D8': ['19891122'], 'L1': ['a']}, '\xe9\xbb\x83\xe6\xb0\xb8\xe6\x9d\xb0']
# ['dgcs109', '71', u'XUEPENGYE', 'hotban@live.com', '13066132016', 'hotban', 'LN606371', 'L4D3', {'L4': ['dgcs'], 'D3': ['109']}, 'XUEPENGYE']
# ['tkp334181', '85605', 'tangjinpei', 'misterpui@msn.com', '18063883650', 'misterpui', 'M0207585605', 'L3D6', {'D6': ['334181'], 'L3': ['tkp']}, '\xe6\xb1\xa4\xe9\x94\xa6\xe5\x9f\xb9']
# ['36124912l', '1986', 'wangluping', 'wlp860125@163.com', '15355022656', 'lpvsss', '3301821986', 'D8L1', {'D8': ['36124912'], 'L1': ['l']}, '\xe7\x8e\x8b\xe9\x99\x86\xe5\xb9\xb3']
# ['a521314', '272', 'jieyunchao', 'macbrady@163.com', '18610501675', 'StevenCa', 'G29404272', 'L1D6', {'D6': ['521314'], 'L1': ['a']}, '\xe8\xa7\xa3\xe8\xbf\x90\xe8\xb6\x85']
# ['5690251', '19000', 'caijunling', 'didiring@qq.com', '13123125599', 'didiring', 'H1028819000', 'D7', {'D7': ['5690251']}, '\xe8\x94\xa1\xe5\x9d\x87\xe7\x8e\xb2']
# ['aa5211', '093', 'linling', '872934775@qq.com', '18502820400', 'moma2046', 'G25095093', 'L2D4', {'D4': ['5211'], 'L2': ['aa']}, '\xe6\x9e\x97\xe5\x87\x8c']
# ['q1w2e3r4', '97', 'yuyuanzong', 'nb110@hotmail.com', '18616389122', 'kt5865', '07343797', 'L1D1L1D1L1D1L1D1', {'D1': ['1', '2', '3', '4'], 'L1': ['q', 'w', 'e', 'r']}, '\xe4\xbd\x99\xe8\xbf\x9c\xe5\xae\x97']
# ['lanshi', '44', 'liudewei', 'tokui@qq.com', '13906009552', 'tokuiliu', '06592044', 'L6', {'L6': ['lanshi']}, '\xe5\x88\x98\xe5\xbe\x97\xe7\x82\x9c']
# ['fev3vw7s', '53100', u'SEN KA MING', 'kms110@msn.com', '15217939535', 'kmsen625', 'H0153753100', 'L3D1L2D1L1', {'L1': ['s'], 'L2': ['vw'], 'L3': ['fev'], 'D1': ['3', '7']}, 'SEN KA MING']
# ['janis123', '51', 'huangjintang', 'jyf.jackson@gmail.com', '13922979757', 'jacksonhuang168', '00668751', 'L5D3', {'L5': ['janis'], 'D3': ['123']}, '\xe9\xbb\x84\xe9\x87\x91\xe5\xa0\x82']
# ['lp011346', '012', 'lipeng', 'lipeng011346@hotmail.com', '18611193998', 'lipeng011345', 'G58510012', 'L2D6', {'D6': ['011346'], 'L2': ['lp']}, '\xe6\x9d\x8e\xe9\xb9\x8f']
# ['5231066', '79', 'jintao', '470430485@qq.com', '18893105389', 'gt5231066', '12564879', 'D7', {'D7': ['5231066']}, '\xe9\x87\x91\xe6\xb6\x9b']
# ['562111068', '72111302', 'zhujusen', '362099657@qq.com', '13616420345', 'a362099657', '220621721113023', 'D9', {'D9': ['562111068']}, '\xe6\x9c\xb1\xe5\xb7\xa8\xe6\xa3\xae']
# ['316443479', '64062151', 'donghongyin', '316443479@qq.com', '13059070035', 'woshi1baba', '413025640621511', 'D9', {'D9': ['316443479']}, '\xe8\x91\xa3\xe5\xae\x8f\xe9\x93\xb6']
# ['19890719k', '1', 'zhangkai', 'vitaszk@163.com', '15515805196', 'vitaszk', '4127251', 'D8L1', {'D8': ['19890719'], 'L1': ['k']}, '\xe5\xbc\xa0\xe5\x87\xaf']
# ['tj712539', '9', 'taojian', 'tjnudt@vip.qq.com', '18689010207', 'tjnudt', '1012429', 'L2D6', {'D6': ['712539'], 'L2': ['tj']}, '\xe9\x99\xb6\xe5\x89\x91']
# ['1878pp', '38300', 'chenyongbin', 'benno520@gmail.com', '13143804362', 'benno520', 'H0127638300', 'D4L2', {'D4': ['1878'], 'L2': ['pp']}, '\xe9\x99\x88\xe5\x8b\x87\xe5\xae\xbe']
# ['226234', '148', 'zhouhongyi', '153417494@qq.com', '13136179058', 'a153417494', 'G47337148', 'D6', {'D6': ['226234']}, '\xe5\x91\xa8\xe6\xb4\xaa\xe7\x9b\x8a']
# ['a8052357', '76900', 'zhouguiying', 'myleleil@tom.com', '15888835743', 'myleleil', 'H0493676900', 'L1D7', {'D7': ['8052357'], 'L1': ['a']}, '\xe5\x91\xa8\xe6\xa1\x82\xe8\x8b\xb1']
# ['qwer1234', '803', 'huanglei', 'tsuk100@sina.com', '18624063324', 'ttssuukk', 'G51663803', 'L4D4', {'L4': ['qwer'], 'D4': ['1234']}, '\xe9\xbb\x84\xe9\x9b\xb7']
# ['910718s', '9', u'zhangsiriporn', 'zhg678b@sina.com', '13806750512', 'wszhy678', 'S974239', 'D6L1', {'D6': ['910718'], 'L1': ['s']}, 'zhangsiriporn']
# ['zyz860817', '964', 'zhengweimin', '172668575@qq.com', '15907451797', 'zwmxmq2014', 'E29283964', 'L3D6', {'D6': ['860817'], 'L3': ['zyz']}, '\xe9\x83\x91\xe4\xbc\x9f\xe6\xb0\x91']
# ['17538509319', '481', 'linshizhao', '332933280@qq.com', '85292696553', 'qq332933280', 'H03188481', 'D11', {'D11': ['17538509319']}, '\xe6\x9e\x97\xe4\xb8\x96\xe9\x87\x97']
# ['28465520', '59100', 'zhenghaobin', 'b444d@163.com', '13903562073', 'zhbhaobin', 'H1030259100', 'D8', {'D8': ['28465520']}, '\xe9\x83\x91\xe8\xb1\xaa\xe6\x96\x8c']
# ['chenzhewei123', '628', 'chenzhewei', '245747927@qq.com', '17686618416', 'czwqwe1', 'E24085628', 'L10D3', {'L10': ['chenzhewei'], 'D3': ['123']}, '\xe9\x99\x88\xe5\x96\x86\xe7\x82\x9c']
# ['o2116238', '05300', 'lixiting', 'jaylee95@hotmail.com', '13928147799', 'orson2211623', 'M0216105300', 'L1D7', {'D7': ['2116238'], 'L1': ['o']}, '\xe6\x9d\x8e\xe6\x9b\xa6\xe5\xba\xad']
# ['a8061918', '19901212', 'mixinyu', 'a8061918@126.com', '18670361786', 'a8061918', '43128119901212', 'L1D7', {'D7': ['8061918'], 'L1': ['a']}, '\xe7\xb3\x9c\xe6\x96\xb0\xe5\xae\x87']
# ['peter123', '179', 'zhaoruqi', '598861360@qq.com', '15846606133', 'z598861360', 'G57248179', 'L5D3', {'L5': ['peter'], 'D3': ['123']}, '\xe8\xb5\xb5\xe5\xa6\x82\xe5\xa5\x87']
# ['yy8fenkai', '199001', 'gepeng', 'cyndifans001@126.com', '13166257371', 'gpvic001', '340321199001', 'L2D1L6', {'L6': ['fenkai'], 'L2': ['yy'], 'D1': ['8']}, '\xe8\x91\x9b\xe9\xb9\x8f']
# ['zw910719', '608', 'zhangwei', '815525644@qq.com', '18637040203', 'zw900518', 'G47122608', 'L2D6', {'D6': ['910719'], 'L2': ['zw']}, '\xe5\xbc\xa0\xe7\xbb\xb4']
# ['tansheng', '81061500', 'liqiang', 'joosuc_rap@126.com', '13006978921', 'jointrap', '450702810615001', 'L8', {'L8': ['tansheng']}, '\xe6\x9d\x8e\xe5\xbc\xba']
# ['www001', '273', 'wangchao', 'handankkk@163.com', '13869032773', 'handankkkk', '218736273', 'L3D3', {'L3': ['www'], 'D3': ['001']}, '\xe7\x8e\x8b\xe8\xb6\x85']
# ['a6430781', '9', 'fuliang', '307445843@qq.com', '13730696412', 'a307445843', '1103209', 'L1D7', {'D7': ['6430781'], 'L1': ['a']}, '\xe5\x82\x85\xe4\xba\xae']
# ['linfeng008', '19841', 'wangsubin', 'wsblovezwl520@163.com', '15051952399', 'wsblovezwl520', '23018419841', 'L7D3', {'D3': ['008'], 'L7': ['linfeng']}, '\xe7\x8e\x8b\xe8\x8b\x8f\xe5\xbd\xac']
# ['ct19870331', '19870731', 'chentao', 'chentao331@163.com', '18699765166', 'cht8256215', '65270119870731', 'L2D8', {'L2': ['ct'], 'D8': ['19870331']}, '\xe9\x99\x88\xe6\xb6\x9b']
# ['sx1988305', '751', 'songjiexin', 'jackme00@126.com', '08035195568', 'linjunqiao1988', 'G51582751', 'L2D7', {'L2': ['sx'], 'D7': ['1988305']}, '\xe5\xae\x8b\xe7\x9a\x86\xe6\xac\xa3']
# ['moon900521', '95300', 'zhongkeming', '295720270@qq.com', '15920417178', 'anemoneming', 'H1036395300', 'L4D6', {'D6': ['900521'], 'L4': ['moon']}, '\xe9\x92\x9f\xe7\xa7\x91\xe6\x98\x8e']
# ['zxc123456', '57700', 'gaoyunhao', '574534610@qq.com', '13826453540', 'tomokey', 'M0218057700', 'L3D6', {'D6': ['123456'], 'L3': ['zxc']}, '\xe9\xab\x98\xe4\xba\x91\xe6\x98\x8a']
# ['123123', '208', u'CHEN BAOLIN', 'ylhed@qq.com', '13819323377', 'ylhed62', '473750208', 'D6', {'D6': ['123123']}, 'CHEN BAOLIN']
# ['yj26787534', '1980112', 'yangjian', 'crazyboyyj@163.com', '15620006251', 'crazyboyyj', '1201011980112', 'L2D8', {'L2': ['yj'], 'D8': ['26787534']}, '\xe6\x9d\xa8\xe5\x81\xa5']
# ['vs2288986', '79601', 'liuyiliang', '451570629@qq.com', '13680308936', 'vs2120806', 'M0204679601', 'L2D7', {'L2': ['vs'], 'D7': ['2288986']}, '\xe5\x88\x98\xe5\xa5\x95\xe8\x89\xaf']
# ['198652', '64700', 'chenshaoxiong', 'chensiuhung@hotmail.com', '13265980360', 'kazuchen', 'H0137764700', 'D6', {'D6': ['198652']}, '\xe9\x99\xb3\xe5\xb0\x91\xe9\x9b\x84']
# ['hulei84828', '198', 'hulei', '200308054@163.com', '18666721668', 'fredcherry', '510181198', 'L5D5', {'L5': ['hulei'], 'D5': ['84828']}, '\xe8\x83\xa1\xe7\xa3\x8a']
# ['jeff920612', '476', 'huayi', '591352224@qq.com', '13813917603', 'rex0jeff', 'G54460476', 'L4D6', {'D6': ['920612'], 'L4': ['jeff']}, '\xe5\x8d\x8e\xe4\xba\xbf']
# ['a19881021', '76601', 'yanjiaming', '358379934@qq.com', '15916403825', 'a358379934', 'H1008676601', 'L1D8', {'D8': ['19881021'], 'L1': ['a']}, '\xe9\xa2\x9c\xe5\x98\x89\xe6\x98\x8e']
# ['swd4h5n1', '614', 'jixunqian', 'superjimmy@126.com', '13835224956', 'superhuaqiqi', 'G47138614', 'L3D1L1D1L1D1', {'L1': ['h', 'n'], 'L3': ['swd'], 'D1': ['4', '5', '1']}, '\xe7\xba\xaa\xe6\xb4\xb5\xe8\xb0\xa6']
# ['19830920', '421', 'guzuguang', 'jokergoo@gmail.com', '13390983858', 'guang920', 'E03298421', 'D8', {'D8': ['19830920']}, '\xe9\xa1\xbe\xe7\xa5\x96\xe5\x85\x89']
# ['991480', '219', u'TSE KA HEI', 'edward-tse@hotmail.com', '85298064365', 'TSEKAHEI', 'T00565219', 'D6', {'D6': ['991480']}, 'TSE KA HEI']
# ['bai198691', '1986', 'wenliang', 'baiwenliang91@126.com', '13677000084', 'woaixye', '1521271986', 'L3D6', {'D6': ['198691'], 'L3': ['bai']}, '\xe6\x96\x87\xe4\xba\xae']
# ['1990abc', '11111101', 'wangjia', '787657238@qq.com', '13324850996', 'a787657238', '111111111111013', 'D4L3', {'D4': ['1990'], 'L3': ['abc']}, '\xe7\x8e\x8b\xe4\xbd\xb3']
# ['r0b0tech', '490', u'Frank Chen', 'frank041973@hotmail.com', '13671954939', 'lensman0419', '711189490', 'L1D1L1D1L4', {'L4': ['tech'], 'D1': ['0', '0'], 'L1': ['r', 'b']}, 'Frank Chen']
# ['jjtan01', '31501', 'tanjinjie', 'crazyjjtam@163.com', '13627289630', 'crazyjjtam', 'H0482031501', 'L5D2', {'L5': ['jjtan'], 'D2': ['01']}, '\xe8\xb0\xad\xe6\x99\x8b\xe6\x9d\xb0']
# ['5220866', '22', 'yelang', 'lys_611@163.com', '15229287830', 'lys_111', '07127022', 'D7', {'D7': ['5220866']}, '\xe5\x8f\xb6\xe6\xb5\xaa']
# ['885168', '2002', 'kangjiaquan', 'jasonkongkimo@hotmail.com', '13929219250', 'JasonKong', '0502402002', 'D6', {'D6': ['885168']}, '\xe5\xba\xb7\xe5\xae\xb6\xe9\x8a\x93']
# ['wbshg8284', '198', 'wubo', 'wubo8284@163.com', '18729543094', 'wubo8284', '610103198', 'L5D4', {'D4': ['8284'], 'L5': ['wbshg']}, '\xe5\x90\xb4\xe5\x8d\x9a']
# ['wq123456', '716', 'wangqi', '61964015@qq.com', '13171893080', 'pauloop', 'G24380716', 'L2D6', {'D6': ['123456'], 'L2': ['wq']}, '\xe7\x8e\x8b\xe7\x90\xaa']
# ['shui336180', '07501', 'xurongyou', 'huiwy08@163.com', '13923738272', 'aw71305', 'H0771907501', 'L4D6', {'D6': ['336180'], 'L4': ['shui']}, '\xe8\xae\xb8\xe8\x8d\xa3\xe7\xa5\x90']
# ['yjm198921', '1989', 'yaojiming', 'yjm4361@163.com', '13761196303', 'yjm4361', '3102271989', 'L3D6', {'D6': ['198921'], 'L3': ['yjm']}, '\xe5\xa7\x9a\xe6\xb4\x81\xe6\x98\x8e']
# ['lpf010248', '994', 'linpeifeng', '624652334@qq.com', '15606002859', 'lpf624652334', 'H04793994', 'L3D6', {'D6': ['010248'], 'L3': ['lpf']}, '\xe6\x9e\x97\xe6\xb2\x9b\xe5\xb3\xb0']
# ['woaini520', '867', 'chenzhao', '673838509@qq.com', '18750734282', 'q673838', 'G345I2867', 'L6D3', {'L6': ['woaini'], 'D3': ['520']}, '\xe9\x99\x88\xe9\x92\x8a']
# ['hippih00', '554', u'PUNG MUN LOON', 'pml_318@hotmail.com', '15901613331', 'pml_318', 'A23825554', 'L6D2', {'L6': ['hippih'], 'D2': ['00']}, 'PUNG MUN LOON']
# ['henry221', '50403', 'huojiasheng', '317834075@qq.com', '13752823441', 'henry1991221', 'H0363050403', 'L5D3', {'L5': ['henry'], 'D3': ['221']}, '\xe9\x9c\x8d\xe5\xae\xb6\xe5\x8d\x87']
# ['lisong', '70092871', 'lixiaohui', 'lisongkjkjkj@163.com', '13883989640', 'lisongkjkj', '513023700928716', 'L6', {'L6': ['lisong']}, '\xe9\xbb\x8e\xe6\x99\x93\xe8\xbe\x89']
# ['yyn9962825', '93401', 'yanyongning', '269994925@qq.com', '15977762470', 'yynatbj', 'H1028693401', 'L3D7', {'L3': ['yyn'], 'D7': ['9962825']}, '\xe9\x98\x8e\xe5\x8b\x87\xe5\xae\x81']
# ['aoeiuu1', '1', 'chenshan', 'aoeiuu1@qq.com', '15101743575', 'aoeiuu_1', '0663561', 'L6D1', {'L6': ['aoeiuu'], 'D1': ['1']}, '\xe8\xb0\x8c\xe5\xb1\xb1']
# ['6229869', '70012200', 'zhangjiale', 'zj520zy@126.com', '13999263541', 'zhangxia12355', '654221700122001', 'D7', {'D7': ['6229869']}, '\xe5\xbc\xa0\xe4\xbd\xb3\xe4\xb9\x90']
# ['123456A', '331', 'wangan', 'andywangan@hotmail.com', '13905600305', 'andywangan323', 'G51081331', 'D6L1', {'D6': ['123456'], 'L1': ['A']}, '\xe7\x8e\x8b\xe5\xae\x89']
# ['zxj3644281', '226', 'duanzhouxiang', 'dzxzxj@yahoo.com.cn', '18614072819', 'SaiDuan', 'G54498226', 'L3D7', {'L3': ['zxj'], 'D7': ['3644281']}, '\xe6\xae\xb5\xe5\x91\xa8\xe7\xbf\x94']
# ['h19890311', '167', 'hubumin', '517060149@qq.com', '13607964228', 'hubumin', 'G32421167', 'L1D8', {'D8': ['19890311'], 'L1': ['h']}, '\xe8\x83\xa1\xe4\xb8\x8d\xe6\x95\x8f']
# ['1223520', '54120415', 'wangtingxi', 'wanglei0987654321@163.com', '18608291272', 'ssss987', '320926541204151', 'D7', {'D7': ['1223520']}, '\xe7\x8e\x8b\xe5\xba\xad\xe5\x96\x9c']
# ['k19900315', '221', u'KEVIN REYEN WANG', 'kevin12x@hotmail.com', '15026504820', 'kevn12x', '452040221', 'L1D8', {'D8': ['19900315'], 'L1': ['k']}, 'KEVIN REYEN WANG']
# ['woaini1314', '59', 'lainantong', '24750250@qq.com', '13003822860', 'qq24750250', '01949959', 'L6D4', {'L6': ['woaini'], 'D4': ['1314']}, '\xe8\xb5\x96\xe6\xa5\xa0\xe6\xa1\x90']
# ['zyh123', '244', 'zhangyuehua', 'zyh4530@yahoo.com', '13075531405', 'zyh4530', 'G42430244', 'L3D3', {'L3': ['zyh'], 'D3': ['123']}, '\xe5\xbc\xa0\xe8\xb7\x83\xe5\x8d\x8e']
# ['123456', '70102562', 'chenmeiping', '479434283@qq.com', '13599091397', 'linshaodaren', '350127701025622', 'D6', {'D6': ['123456']}, '\xe9\x99\x88\xe6\xa2\x85\xe5\xb9\xb3']
# ['woshijinli', '72052020', u'jinli', '420766402@qq.com', '13666666666', 'kinley112', '330302720520204', 'L10', {'L10': ['woshijinli']}, 'jinli']
# ['hc252593', '19781224', 'huangchen', 'hc5000@163.com', '15860799903', 'dans5000', '35020419781224', 'L2D6', {'D6': ['252593'], 'L2': ['hc']}, '\xe9\xbb\x84\xe6\x99\xa8']
# ['a8875035', '1', 'yulei', 'a65875434@163.com', '15236709694', 'a65875434', '4115221', 'L1D7', {'D7': ['8875035'], 'L1': ['a']}, '\xe4\xbd\x99\xe7\xa3\x8a']
# ['s12345', '32', 'chenzhenwen', 'sky8088500@gmail.com', '18800600423', 'sky8088500', '04039932', 'L1D5', {'D5': ['12345'], 'L1': ['s']}, '\xe6\xb2\x88\xe6\x8c\xaf\xe6\x96\x87']
# ['king1414', '15903', 'linhuigen', 'linhuigen1989@yahoo.com.hk', '18650508279', 'matthewlam0711', 'H0320615903', 'L4D4', {'L4': ['king'], 'D4': ['1414']}, '\xe6\x9e\x97\xe6\x83\xa0\xe6\xa0\xb9']
# ['asas5555', '21', 'bianzhengkun', '669855170@qq.com', '13872855170', 'cxcxcx5555', '12099121', 'L4D4', {'L4': ['asas'], 'D4': ['5555']}, '\xe5\x8d\x9e\xe6\x94\xbf\xe5\x9d\xa4']
# ['wks135', '1', 'wangkaisheng', 'wkskaisheng@163.com', '13536215240', 'wks1331', '4108111', 'L3D3', {'L3': ['wks'], 'D3': ['135']}, '\xe7\x8e\x8b\xe5\x87\xaf\xe5\xa3\xb0']
'yi', 'bi', 'pi', 'mi', 'di', 'ti', 'ni', 'li', 'ji', 'qi', 'xi', 'ya', 'dia', 'nia', 'lia', 'jia',
'qia', 'xia', 'yo', 'ye', 'bie', 'pie', 'mie', 'die', 'tie', 'nie', 'lie', 'jie', 'qie', 'xie', 
'yai', 'yao', 'biao', 'piao', 'miao', 'fiao', 'diao', 'tiao', 'niao', 'liao', 'jiao', 'qiao', 
'xiao', 'you', 'miu', 'diu', 'niu', 'liu', 'jiu', 'qiu', 'xiu', 'yan', 'bian', 'pian', 'mian', 
'dian', 'tian', 'nian', 'lian', 'jian', 'qian', 'xian', 'yin', 'bin', 'pin', 'min', 'nin', 'lin', 
'jin', 'qin', 'xin', 'yang', 'biang', 'diang', 'niang', 'liang', 'jiang', 'qiang', 'xiang', 'ying',
'bing', 'ping', 'ming', 'ding', 'ting', 'ning', 'ling', 'jing', 'qing', 'xing', 'wu', 'bu', 'pu', 
'mu', 'fu', 'du', 'tu', 'nu', 'lu', 'gu', 'ku', 'hu', 'zhu', 'chu', 'shu', 'ru', 'zu', 'cu', 'su', 
'wa', 'gua', 'kua', 'hua', 'zhua', 'chua', 'shua', 'rua', 'wo', 'duo', 'tuo', 'nuo', 'luo', 'guo', 
'kuo', 'huo', 'zhuo', 'chuo', 'shuo', 'ruo', 'zuo', 'cuo', 'suo', 'wai', 'guai', 'kuai', 'huai', 
'zhuai', 'chuai', 'shuai', 'wei', 'dui', 'tui', 'gui', 'kui', 'hui', 'zhui', 'chui', 'shui', 'rui',
'zui', 'cui', 'sui', 'wan', 'duan', 'tuan', 'nuan', 'luan', 'guan', 'kuan', 'huan', 'zhuan', 
'chuan', 'shuan', 'ruan', 'zuan', 'cuan', 'suan', 'wen', 'dun', 'tun', 'nun', 'lun', 'gun', 'kun',
'hun', 'zhun', 'chun', 'shun', 'run', 'zun', 'cun', 'sun', 'wang', 'guang', 'kuang', 'huang', 
'zhuang', 'chuang', 'shuang', 'weng', 'dong', 'tong', 'nong', 'long', 'gong', 'kong', 'hong', 
'zhong', 'chong', 'shong', 'rong', 'zong', 'cong', 'song', 'yu', 'nv', 'lv', 'ju', 'qu', 'xu',
'yue', 'nve', 'lve', 'jue', 'que', 'xue', 'yuan', 'juan', 'quan', 'xuan', 'yun', 'lvn', 
'jun', 'qun', 'xun', 'yong', 'jiong', 'qiong', 'xiong']

print len(ptable)
print matchpinyin("huochepiaozyl123piaoliang",ptable)



pinyinlist = []
stringlist = []
stringmatchlist = []
for each in mpwd:
    password = each[0]
    remainder = matchsub(password,each)
    remainder2 = remainder
    for tag in ("[NAME]","[BD]","[EMAIL]","[CELL]","[ACCT]","[ID]"):
        remainder = remainder.replace(tag," ")
        remainder2 = remainder2.replace(tag,"")
        
    toproc2 = re.sub("[^a-zA-Z]+", "", remainder2)
    stringlist.append(toproc2)
    stringmatchlist.append(matchpinyin(toproc2,ptable).replace("\t",""))
    for each in remainder.split():
        toproc = re.sub("[^a-zA-Z]+", "", each)
        pinform = matchpinyin(toproc,ptable)
        add = pinform.split('\t')
        pinyinlist.extend(add)
stringlist = filter(None,stringlist)
stringmatchlist = filter(None,stringmatchlist)
pinyinlist = filter(None, pinyinlist)
x = sortlist(stringlist,20)
y = sortlist(stringmatchlist,20)
z = sortlist(pinyinlist,20)
print len(stringlist)
fout = open(workspace+"simpledic","w")
for each in stringlist:
    fout.write(each + "\n")
fout.close()
print addstring([x.split('\n'),y.split('\n'),z.split('\n')])

# %%
fperfect = open("perfectdic","w")
perfectdic = []

for i in range(len(mpwd)/2,len(mpwd)):
    for item in mpwd[i][-2]:
        if "L" in item:
            for letter in mpwd[i][-2][item]:
                perfectdic.append(letter)

perfectset = list(set(perfectdic))
for each in perfectset:
    fperfect.write(each+"\n")
fperfect.close()

# %%
#--------THIS SECTION ANALYZE DIFFERENT PASSWORD IN DIFFERENT GROUPS (GENDER,AGE,ETC)------
# Out:
# 9856 9856 35465 70002 25922
# 9856
# |[ACCT]|5965|4.53%
# |[BD]|5963|4.53%
# |D7|5147|3.91%
# |[EMAIL]|4550|3.46%
# |[NAME][BD]|4387|3.33%
# |D6|3776|2.87%
# |D8|3051|2.32%
# |L1D7|2265|1.72%
# |[NAME]|1872|1.42%
# |[NAME]D7|1509|1.14%
# |[NAME]D3|1476|1.12%
# |D9|1228|0.93%
# |[NAME]D6|1214|0.92%
# |L2D7|1189|0.90%
# |[EMAIL][BD]|1187|0.90%
# |[EMAIL]D4|1090|0.82%
# |L6D3|1083|0.82%
# |L1D8|1076|0.81%
# |D7L1|1009|0.76%
# |L8|976|0.74%
# |L1D6|968|0.73%
# |L2D6|950|0.72%
# |L4D4|899|0.68%
# |[EMAIL]D6|888|0.67%
# |[EMAIL][EMAIL]|856|0.65%
# |[ACCT]D3|844|0.64%
# |L6|842|0.64%
# |[BD][NAME]|826|0.62%
# |L5D3|821|0.62%
# |L3D6|821|0.62%
# |L4[BD]|769|0.58%
# |[EMAIL]D5|738|0.56%
# |L3D7|731|0.55%
# |L2[BD]|730|0.55%
# |[BD]D4|728|0.55%
# |[EMAIL]D3|719|0.54%
# |L7D3|711|0.54%
# |[EMAIL]D7|705|0.53%
# |L3[BD]|671|0.51%
# |[ACCT][BD]|658|0.50%
# |[NAME][EMAIL]|654|0.49%
# |L3D3|627|0.47%
# |D4[EMAIL]|606|0.46%
# |D10|589|0.44%
# |L7|580|0.44%
# |[NAME]D4|562|0.42%
# |[ID]|554|0.42%
# |L6D4|550|0.41%
# |D5[EMAIL]|518|0.39%
# |D8L1|509|0.38%
# >>>>>>>>>>

# %%
#--------THIS SECTION SHOWS THE COVERAGE WITH DIFFERENT WINDOW SIZE-----------
for window in range(1,8):
    ttrate = 0
    for i in range(0,len(mpwd)):
        ttrate += newcvg(mpwd[i],window)
        
    print ttrate/len(mpwd)
# Out:
# 0.926415428733
# 0.608551803874
# 0.389267476492
# 0.297213532991
# 0.229256094278
# 0.206562296166
# 0.147586106296

# %%
#--------AVG LENGTH OF PASSWORDS----------
#SHORTEST PASSWORD AND THE DISTRIBUTION OF PASSWORDS
#FIND THE MOST FREQUEN STRUCTURE
leng = 0.0
for each in mpwd:
    leng+=len(each[0])
print "AVE LENGTH OF PASSWORD IS: "+str(leng/len(mpwd))

short =100
for each in mpwd:
    if short > len(each[0]):
        short = len(each[0])
    if len(each[0]) == 4:
        print "SHORTEST: " + each[0]
print short#THERE IS ONE PASSWORD OF LENGTH 4 (5700), all other passwords have longer length at least 7
hello = distri(mpwd,0)
for each in hello:
    print "|"+each[0]+"|"+str(each[1]*100)[:5]+"%|"

print ">>>>>>>>>>>>>>>>>>>>>>>>>>>"
sorted_x = sorted(segdic.items(), key=operator.itemgetter(1))
for i in range(len(sorted_x)-1,len(sorted_x)-21,-1):
    print "|"+ sorted_x[i][0] + "|"+ str(sorted_x[i][1])+"|"+str(float(sorted_x[i][1])/len(lines)*100)[:5]+"%|"
# Out:
# AVE LENGTH OF PASSWORD IS: 8.43834719802
# 5700
# XX
# 4
# |123456|0.296%|
# |a123456|0.213%|
# |123456a|0.125%|
# |5201314|0.121%|
# |111111|0.118%|
# |woaini1314|0.101%|
# |qq123456|0.074%|
# |123123|0.073%|
# |000000|0.073%|
# |1qaz2wsx|0.070%|
# |1q2w3e4r|0.062%|
# |qwe123|0.060%|
# |7758521|0.057%|
# |123qwe|0.051%|
# |a123123|0.047%|
# |123456aa|0.041%|
# |woaini520|0.041%|
# |1314520|0.039%|
# |100200|0.039%|
# |woaini|0.038%|
# >>>>>>>>>>>>>>>>>>>>>>>>>>>
# |D7|10906|8.283%|
# |D8|9458|7.184%|
# |D6|9102|6.913%|
# |L2D7|5073|3.853%|
# |L3D6|4832|3.670%|
# |L1D7|4778|3.629%|
# |L2D6|4275|3.247%|
# |L3D7|3885|2.950%|
# |D9|3594|2.729%|
# |L2D8|3371|2.560%|
# |L4D4|3105|2.358%|
# |L1D8|3103|2.356%|
# |L6D3|2798|2.125%|
# |L6D4|2476|1.880%|
# |L7D3|2192|1.664%|
# |L5D3|2158|1.639%|
# |L5D4|2125|1.614%|
# |L8|2079|1.579%|
# |D7L1|1973|1.498%|
# |L3D4|1879|1.427%|

# %%
#SERVICE INFO: TIANYA IN TIANYA DATABASE, ETC
count  = []
ttentry = 0
tianya = ["tianya","tya","tiany"]
rockyou = ["rockyou","rock","rocky","ryou"]
myspace = ["myspace","space","mspace"]
phpbb = ["phpbb","php","phpb","pbb"]
t12306 = ["12306","1230","2306"]


for filenumber in range (1,49):
    try:
        f2 = open("/Users/liyue/research/DATA/password/tianya/tianya_"+str(filenumber)+".txt","r")
        haha = f2.readlines()
        for each in haha:
            ttentry += 1
            info = each.split()
            try:
                for every in tianya:
                    if every in info[1].lower():
                        count.append(info[1])
                        break
            except:
                pass
                #print info
        f2.close()
    except:
        print filenumber
print len(count)
print ttentry
print float(len(count))/ttentry
print sortlist(count,10)
    


f3 = open("/Users/liyue/research/DATA/password/rockyou.txt","r")

haha = f3.readlines()
count  = []
for each in haha:
    info = each.split()
    try:
        for every in rockyou:
            if every in info[0].lower():# or "you" in info[0].lower():
                count.append(info[0])
                break
    except:
        pass
print len(count)
print len(haha)
print float(len(count))/len(haha)
print sortlist(count,10)
f3.close()

f3 = open("/Users/liyue/research/DATA/password/phpbb.txt","r")

haha = f3.readlines()
count  = []
for each in haha:
    info = each.split()
    try:
        for every in phpbb:
            if every in info[0].lower():# or "you" in info[0].lower():
                count.append(info[0])
                break
    except:
        pass
print len(count)
print len(haha)
print float(len(count))/len(haha)
print sortlist(count,10)
f3.close()


f3 = open("/Users/liyue/research/DATA/password/myspace.txt","r")

haha = f3.readlines()
count  = []
for each in haha:
    info = each.split()
    try:
        for every in myspace:
            if every in info[0].lower():# or "you" in info[0].lower():
                count.append(info[0])
                break
    except:
        pass
print len(count)
print len(haha)
print float(len(count))/len(haha)
print sortlist(count,10)
f3.close()

# %%
count  = []
for each in mpwd:
    for every in t12306:
        if every in each[0].lower():
            count.append(each[0])
            break
        
        
print len(count)
print len(mpwd)
print float(len(count))/len(mpwd)
print sortlist(count,10)
# Out:
# 490
# 131389
# 0.00372938373836
# 123000&17&3.469\%
# 1230123&9&1.836\%
# a123000&7&1.428\%
# a12301230&7&1.428\%
# 19861230&6&1.224\%
# 1230456&5&1.020\%
# wang1230&5&1.020\%
# 19871230&4&0.816\%
# 12301230&4&0.816\%
# 12312300&4&0.816\%

# %%
# Out:
# 23085

# %%
# --------GENERATE TRAINING AND TESTING SET FOR PCFG---------
fout = open(workspace+"trainingset","w")
fout2 = open(workspace+"testingset","w")
for i in range(0,len(mpwd)/2):
    fout.write(mpwd[i][0]+"\n")
for i in range(len(mpwd)/2,len(mpwd)):
    fout2.write(mpwd[i][0] + "\n")
fout.close()
fout2.close()

# %%
## ---------PCFG STYLE PERSONAL FORM-----------
struc = []
print matchpersonal(mpwd[65873])

for i in range(0,len(mpwd)/2):
    form = matchpersonal(mpwd[i])
    struc.append(form)
print len(struc)

print sortlist(struc,20)
# Out:
# LBBBBBBBB
# 65694
# DDDDDDD	0.0276737601607
# DDDDDD	0.0196364964837
# LDDDDDDD	0.0195908302128
# DDDDDDDD	0.0161354157153
# BBBBBBBB	0.0146284287758
# BBBBBB	0.0103814655829
# LDDDDDDDD	0.00998569123512
# NNNDDDDDDD	0.00981824824185
# NNDDDDDDD	0.00910280999787
# LLDDDDDDD	0.00901147745608
# DDDDDDDL	0.00898103327549
# AAAAAAA	0.00875270192103
# LLLLLLDDD	0.00873747983073
# LDDDDDD	0.00809815203824
# EEEEEEEEE	0.00786982068378
# LLDDDDDD	0.00720004871069
# NNNBBBBBB	0.0071543824398
# AAAAAAAA	0.00709349407861
# NNNDDDDDD	0.00703260571742
# NNBBBBBBBB	0.00671294182117

# %%
import string
f = open("testingset","w")
for i in range(len(mpwd)/2,len(mpwd)):
    try:
        f.write(mpwd[i][0]+"\t"+mpwd[i][1]+"\t"+printname(mpwd[i][-1])+"\t"+mpwd[i][3]+"\t"+\
             mpwd[i][4]+"\t"+mpwd[i][5]+"\t"+mpwd[i][6]+"\n")
    except:
        f.write(mpwd[i][0]+"\t"+mpwd[i][1]+"\t"+filter(lambda x: x in string.printable, printname(mpwd[i][-1]))+"\t"+mpwd[i][3]+"\t"+\
             mpwd[i][4]+"\t"+mpwd[i][5]+"\t"+mpwd[i][6]+"\n")
f.close()

# %%
tmp = []
for each in mpwd:
    tmp.extend(matchpersonal(each).split())

# %%
print matchpersonal(mpwd[9])
regex = re.compile('[^a-zA-Z]')
perfectpersonaldic = []
for each in tmp:
    if "[" in each and "]" in each:
        continue
    word = regex.sub('', each)
    if word != "":
        perfectpersonaldic.append(word)
ff = open("perfectdic_personal","w")
print len(perfectpersonaldic)
print len(set(perfectpersonaldic))
for each in set(perfectpersonaldic):
    ff.write(each+"\n")
ff.close()
# Out:
# 	a2654	[EMAIL]	28
# 59862
# 15466

# %%
###SEC 2.1.2
print "###SEC 2.1.2#### -- table1 and table2"
pwd = []
ct = 0
for each in mpwd:
    pwd.append(each[0])
print len(mpwd)
print sortlist(pwd,10)
####SEC 2.1.2
struct =[]
for each in mpwd:
    struct.append(seg(each[0])[0])
print sortlist(struct,10)

#SEC 2.2.3
print "###SEC 2.2.3#### -- table 3 and table 4"
struct = []

for each in mpwd:
    eachstru = matchpersonal(each)
    struct.append(eachstru)

print len(struct)

dupstruct = []
for each in struct:
    if "&" in each:
        rst = []
        disamb(each,rst)
        dupstruct.extend(rst)
    else:
        dupstruct.append(each)
        
ct = 0
for each in struct:
    if "&" in each:
        ct+=1
print "AMBIGUOUS STRUCTURE: ",ct
print len(struct),len(dupstruct)
print sortlist(dupstruct,10)

tt = 0 
for each in struct:
    if "[" in each:
        tt+=1
print float(tt)/len(struct),tt,len(struct)

#---------THIS SECTION ANALYZE WHICH IS THE MOST POPULAR PERSONAL INFO IN PASSWORDS------
populardic = {}
for personal in ("[BD]","[NAME]","[EMAIL]","[CELL]","[ACCT]","[ID]"):
    populardic[personal] = 0
    for each in struct:
        if personal in each:
            populardic[personal]+=1
    print "&" + personal + "&" + str(populardic[personal]) + "&" + str(populardic[personal]/131389.0 * 100)[:5] + "\%\\\\"
###Sec 2.2.4####
print "###Sec 2.2.4#### ---- table 5 and table 6"
malepwd = []
femalepwd = []
youngpwd = []
adultpwd = []
oldpwd = []

for each in mpwd:
    if int(each[6][-2]) % 2 == 0:
        femalepwd.append(each)
    else:
        malepwd.append(each)
    if (2014 - int(each[1][:4])) > 30:
        oldpwd.append(each)
    elif (2014-int(each[1][:4])) < 25:
        youngpwd.append(each)
    else:
        adultpwd.append(each)
print len(femalepwd),len(malepwd[0:len(femalepwd)]),  len(youngpwd),len(adultpwd),len(oldpwd)
newmalepwd = []

for i in random.sample(range(0,len(malepwd)),len(femalepwd)):
    newmalepwd.append(malepwd[i])
print len(newmalepwd)
print len(femalepwd)
mlist = []
for targetpwdlist in(newmalepwd,femalepwd):
#if True:
#    targetpwdlist = mpwd
    tt = 0
    allform = []
    tmp = []
    pwd = []
    tt = 0
    personalc = 0
    for i in range(0,len(targetpwdlist)):
        tt += len(targetpwdlist[i][0])
        pwd.append(targetpwdlist[i][0])
        myform = matchpersonal(targetpwdlist[i])
        allform.append(myform)
    for each in allform:
        if "[" in each:
            personalc += 1
    for each in allform:
        if "&" in each:
            rst = []
            disamb(each,rst)
            tmp.extend(rst)
        else:
            tmp.append(each)
    allform = tmp
    print "Passworld length:" ,float(tt)/len(targetpwdlist)
    mlist.append(sortlist(allform,12).split("\n"))
    #print sortlist(pwd,12)
    
    print "persons with personal info: " + str(personalc)
    print "All structures: ",len(set(allform))
    print ">>>>>>>>>>"
print addstring(mlist)

print "###SEC 2.2.4####"

#---------THIS SECTION ANALYZE WHICH IS THE MOST POPULAR PERSONAL INFO IN PASSWORDS------
mlist = []
for xlist in (newmalepwd,femalepwd):
    allform = []
    tmp = []
    for each in xlist:
        allform.append(matchpersonal(each))
    populardic = {}
    out = ""
    for personal in ("[BD]","[NAME]","[EMAIL]","[CELL]","[ACCT]","[ID]"):
        populardic[personal] = 0
        for each in allform:
            if personal in each:
                populardic[personal]+=1
        out += "&" + personal + "&" + str(populardic[personal]/9856.0 * 100)[:5] + "\%\n"
    mlist.append(out.split("\n"))
print addstring(mlist)
# Out:
# ###SEC 2.1.2#### -- table1 and table2
# 131389
# 123456&389&0.296\%
# a123456&280&0.213\%
# 123456a&165&0.125\%
# 5201314&160&0.121\%
# 111111&156&0.118\%
# woaini1314&134&0.101\%
# qq123456&98&0.074\%
# 123123&97&0.073\%
# 000000&96&0.073\%
# 1qaz2wsx&92&0.070\%
# D7&10893&8.290\%
# D8&9442&7.186\%
# D6&9084&6.913\%
# L2D7&5065&3.854\%
# L3D6&4820&3.668\%
# L1D7&4770&3.630\%
# L2D6&4261&3.243\%
# L3D7&3883&2.955\%
# D9&3590&2.732\%
# L2D8&3362&2.558\%
# ###SEC 2.2.3#### -- table 3 and table 4
# 131389
# AMBIGUOUS STRUCTURE:
#  9912
# 131389 143373
# D7&7122&4.967\%
# [ACCT]&6820&4.756\%
# [NAME][BD]&5410&3.773\%
# D6&4886&3.407\%
# [BD]&4470&3.117\%
# D8&4245&2.960\%
# [EMAIL]&3807&2.655\%
# L1D7&3296&2.298\%
# [NAME]D7&2949&2.056\%
# [NAME]D3&2363&1.648\%
# 0.539558106082 70892 131389
# &[BD]&32373&24.63\%\\
# &[NAME]&29646&22.56\%\\
# &[EMAIL]&11020&8.387\%\\
# &[CELL]&634&0.482\%\\
# &[ACCT]&21324&16.22\%\\
# &[ID]&1210&0.920\%\\
# ###Sec 2.2.4#### ---- table 5 and table 6
# 9856
#  9856 35465 70002 25922
# 9856
# 9856
# Passworld length:
#  8.4242086039
# persons with personal info: 5502
# All structures:  1114
# >>>>>>>>>>
# Passworld length:
#  8.51156655844
# persons with personal info: 4399
# All structures:  1194
# >>>>>>>>>>
# D7&548&5.082\%D6&482&4.562\%
# [ACCT]&542&5.026\%D7&416&3.937\%
# [NAME][BD]&444&4.117\%[ACCT]&415&3.928\%
# D6&365&3.384\%D8&321&3.038\%
# [BD]&354&3.282\%[EMAIL]&264&2.499\%
# D8&305&2.828\%[NAME][BD]&257&2.432\%
# [EMAIL]&292&2.707\%[BD]&219&2.073\%
# [NAME]D7&257&2.383\%L2D6&205&1.940\%
# L1D7&238&2.207\%L2D7&168&1.590\%
# [NAME]D3&198&1.836\%L1D7&166&1.571\%
# [NAME]D6&164&1.520\%L3D6&165&1.561\%
# D9&142&1.316\%L6D3&147&1.391\%
#
#
# ###SEC 2.2.4####
# &[BD]&25.26\%&[BD]&21.14\%
# &[NAME]&24.36\%&[NAME]&13.02\%
# &[EMAIL]&8.614\%&[EMAIL]&8.806\%
# &[CELL]&0.476\%&[CELL]&0.405\%
# &[ACCT]&16.84\%&[ACCT]&15.35\%
# &[ID]&0.903\%&[ID]&0.446\%

# %%
#Section 3.2
import numpy as np
import time
import matplotlib.pyplot as plt
# %matplotlib inline
#for target in (mpwd,newmalepwd,femalepwd):
if True:
    target =mpwd
    ttcvg = 0
    cvglist = []
    for each in target:
        mcvg = dynacvg(each)
        ttcvg += mcvg
        cvglist.append(mcvg)
    print ttcvg/len(target)
# Out:
# 0.309171917535

# %%
    data = cvglist
    sorted_data = np.sort(data)  # Or data.sort(), if data can be modified
    # Cumulative distributions:
    plt.step(sorted_data, np.arange(sorted_data.size)/float(len(cvglist)),label="12306",color="blue")  # From 0 to the number of data points-1
    x1 = 0.184
    y = 0.5
    plt.plot([0, x1], [y, y], color='blue', linewidth=0.8)
    plt.plot([x1, x1], [y, 0], color='blue', linewidth=0.8)
    plt.xticks(np.arange(0, 1.1, 0.1))
    plt.yticks(np.arange(0, 1.1, 0.1))
    plt.ylabel('Cumulative Probability')
    plt.xlabel('Coverage')
    plt.grid()
    plt.show()

# %%
import pickle
newmalepwd = pickle.load( open( "male.p", "rb" ) )
print len(newmalepwd)
# Out:
# 9856

# %%
def distort(st):#add 1
    newst = ""
    for each in st:
        od = ord(each)
        if od >= 48 and od < 57:
            newst += chr(od+1)
        elif od == 57:
            newst += chr(48)
        elif od >=97 and od < 122:
            newst += chr(od+1)
        elif od == 122:
            newst += chr(97)
        else:
            newst+= each
    return newst

def distort2(pwd):#add pi
    mypi = "31415926535897931159979634685441851615906"
    newst = ""
    for i in range (0, len(pwd)):
        od = ord(pwd[i])
        if od >= 48 and od <= 57: #a number
            newod = od + int(mypi[i])
            if newod > 57:
                newod = (newod%58) + 48
            newst+=chr(newod)
        elif od >= 97 and od <= 122:
            newod = od + int(mypi[i])
            if newod > 122:
                newod = (newod%123) + 97
            newst+=chr(newod)
        else:
            newst+=pwd[i]
    return newst

def distort3(pwd):#gap 0
    newst = ""
    for each in pwd:
        newst += each + "0"
    return newst[:-1]

def distort4(pwd):#gap a
    newst = ""
    for each in pwd:
        newst += each + "a"
    return newst[:-1]

def distort5(pwd):#gap !
    newst = ""
    for each in pwd:
        newst += each + "!"
    return newst[:-1]

# %%
#for target in (mpwd,newmalepwd,femalepwd):

def unshared_copy(inList):
    if isinstance(inList, list):
        return list( map(unshared_copy, inList) )
    return inList


newmpwd = unshared_copy(mpwd)
new2pwd = unshared_copy(mpwd)
new3pwd = unshared_copy(mpwd)
new4pwd = unshared_copy(mpwd)
new5pwd = unshared_copy(mpwd)

print newmpwd[0]
for each in newmpwd:
    each[0] = distort(each[0])
for each in new2pwd:
    each[0] = distort2(each[0])
for each in new3pwd:
    each[0] = distort3(each[0])
for each in new4pwd:
    each[0] = distort4(each[0])
for each in new5pwd:
    each[0] = distort5(each[0])

if True:
    target =newmpwd
    ttcvg = 0
    newcvglist = []
    for each in target:
        mcvg = dynacvg(each)
        ttcvg += mcvg
        newcvglist.append(mcvg)
    print ttcvg/len(target)
    
    target =new2pwd
    ttcvg = 0
    new2cvglist = []
    for each in target:
        mcvg = dynacvg(each)
        ttcvg += mcvg
        new2cvglist.append(mcvg)
    print ttcvg/len(target)
    
    target =new3pwd
    ttcvg = 0
    new3cvglist = []
    for each in target:
        mcvg = dynacvg(each)
        ttcvg += mcvg
        new3cvglist.append(mcvg)
    print ttcvg/len(target)
    
    target =new4pwd
    ttcvg = 0
    new4cvglist = []
    for each in target:
        mcvg = dynacvg(each)
        ttcvg += mcvg
        new4cvglist.append(mcvg)
    print ttcvg/len(target)
    
    target =new5pwd
    ttcvg = 0
    new5cvglist = []
    for each in target:
        mcvg = dynacvg(each)
        ttcvg += mcvg
        new5cvglist.append(mcvg)
    print ttcvg/len(target)
# Out:
# ['6837605', '19870504', 'zhengyifeng', '274667266@qq.com', '15068860664', 'z6837605', '332522198705040011', 'D7', {'D7': ['6837605']}, '\xe9\x83\x91\xe4\xb8\x80\xe5\xb3\xb0']
# 0.0746409026201
# 0.0670857092271
# 0.0619540589075
# 0.00877181621496
# 0.0

# %%
sorted_d = np.sort(new2cvglist)
print sorted_d[len(new2cvglist)
# Out:
# 0.504132231405

# %%
    data = cvglist
    sorted_data = np.sort(data)  # Or data.sort(), if data can be modified
    # Cumulative distributions:
    plt.plot(sorted_data, np.arange(sorted_data.size)/float(len(cvglist)),label="Before",ls="--",color="blue")  # From 0 to the number of data points-1

    data = newcvglist
    sorted_data = np.sort(data)  # Or data.sort(), if data can be modified
    # Cumulative distributions:
    plt.plot(sorted_data, np.arange(sorted_data.size)/float(len(newcvglist)),label="After D1",color="red")  # From 0 to the number of data points-1

    data = new2cvglist
    sorted_data = np.sort(data)  # Or data.sort(), if data can be modified
    # Cumulative distributions:
    plt.plot(sorted_data, np.arange(sorted_data.size)/float(len(cvglist)),label="After D2",ls="-.",color="green")  # From 0 to the number of data points-1

    data = new2cvglist
    sorted_data = np.sort(data)  # Or data.sort(), if data can be modified
    # Cumulative distributions:
    plt.plot(sorted_data, np.arange(sorted_data.size)/float(len(cvglist)),label="After D2",ls="-.",color="green")  # From 0 to the number of data points-1

    data = new2cvglist
    sorted_data = np.sort(data)  # Or data.sort(), if data can be modified
    # Cumulative distributions:
    plt.plot(sorted_data, np.arange(sorted_data.size)/float(len(cvglist)),label="After D2",ls="-.",color="green")  # From 0 to the number of data points-1

    markline = '''x1 = 0.0625
    x2 = 0.184
    y = 0.5
    plt.plot([x1, x2], [y, y], color='blue', linewidth=1.5, linestyle="--")
    plt.plot([0, x1], [y, y], color='red', linewidth=1.5)
    plt.plot([x1, x1], [y, 0], color='red', linewidth=1.5)
    plt.plot([x2, x2], [y, 0], color='blue', linewidth=1.5, linestyle="--")
    
    x1 = 0.125
    x2 = 0.556
    x3 = 0.018
    y = 0.8
    plt.plot([x1, x2], [y, y], color='blue', linewidth=1.5, linestyle="--")
    plt.plot([0, x3], [y, y], color='green', linewidth=1.5)
    plt.plot([x3, x3], [y, 0], color='green', linewidth=1.5,ls="-.")
    plt.plot([x1, x3], [y, y], color='red', linewidth=1.5)
    plt.plot([x1, x1], [y, 0], color='red', linewidth=1.5)
    plt.plot([x2, x2], [y, 0], color='blue', linewidth=1.5, linestyle="--")'''

    plt.ylabel('Cumulative Probability')
    plt.xlabel('Coverage')
    plt.legend(bbox_to_anchor=(1, 0.35))
    plt.xticks(np.arange(0, 1.1, 0.1))
    plt.yticks(np.arange(0, 1.1, 0.1))
    plt.grid()
    plt.show()

# %%
    data = cvglist
    sorted_data = np.sort(data)  # Or data.sort(), if data can be modified
    # Cumulative distributions:
    plt.plot(sorted_data, np.arange(sorted_data.size)/float(len(cvglist)),label="$\mathregular{Before}$",ls="-",color="blue")  # From 0 to the number of data points-1

    data = newcvglist
    sorted_data = np.sort(data)  # Or data.sort(), if data can be modified
    # Cumulative distributions:
    plt.plot(sorted_data, np.arange(sorted_data.size)/float(len(newcvglist)),label="$\mathregular{add_1}$",color="red")  # From 0 to the number of data points-1

    data = new2cvglist
    sorted_data = np.sort(data)  # Or data.sort(), if data can be modified
    # Cumulative distributions:
    plt.plot(sorted_data, np.arange(sorted_data.size)/float(len(cvglist)),label="$\mathregular{add_{pi}}$",ls="-.",linewidth = 2, color="green")  # From 0 to the number of data points-1

    data = new3cvglist
    sorted_data = np.sort(data)  # Or data.sort(), if data can be modified
    # Cumulative distributions:
    plt.plot(sorted_data, np.arange(sorted_data.size)/float(len(cvglist)),ls = "--",label="$\mathregular{gap_0}$",color="black")  # From 0 to the number of data points-1

    data = new4cvglist
    sorted_data = np.sort(data)  # Or data.sort(), if data can be modified
    # Cumulative distributions:
    plt.plot(sorted_data, np.arange(sorted_data.size)/float(len(cvglist)),ls=":",label="$\mathregular{gap_a}$",lw=2,color="m")  # From 0 to the number of data points-1

 
    
    plt.plot([0, 1], [0.5, 0.5], color="black", linewidth=1)
    plt.plot([0, 1], [0.8, 0.8], color="black", linewidth=1)
    plt.ylabel('Cumulative Probability')
    plt.xlabel('Coverage')
    plt.legend(prop={'size':13},bbox_to_anchor=(1, 0.6))
    plt.xticks(np.arange(0, 1.1, 0.1))
    plt.yticks(np.arange(0, 1.1, 0.1))
    plt.grid()
    plt.show()

# %%
fml = 0
ml = 0
f = open("/Users/liyue/research/DATA/12306/output_personal.txt","r")
lines = f.readlines()
for each in lines:
    parts = each.split()
    idn = parts[-1]
    if int(idn[-2])%2 == 0:
        fml+=1
    else:
        ml += 1
print fml, ml
print fml/9856.0,ml/121533.0
# Out:
# 429 9524
# 0.0435267857143 0.0783655468062

# %%
# Out:
# [7]
