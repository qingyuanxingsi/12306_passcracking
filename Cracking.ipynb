# %%
import time
import matplotlib.pyplot as plt
# %matplotlib inline

output = open("PCFG_output.txt","r")
lines = output.readlines()
xpoints = [0]
ypoints = [0]
lastind = 1
total = 0
for each in lines:
    point = each.split()
    total+=1
    if int(point[0]) != lastind:
        xpoints.append(lastind)
        ypoints.append(total/65695.0)
        lastind = int(point[0])
output.close()

output = open("output_personalPCFG.txt","r")
lines = output.readlines()
x2points = [0]
y2points = [0]
lastind = 1
total = 0
for each in lines:
    point = each.split()
    total+=1
    if int(point[0]) != lastind:
        x2points.append(lastind/20000.0)
        y2points.append(total/65695.0)
        lastind = int(point[0])        

output = open("output_personalPCFG_guessmatch.txt","r")
lines = output.readlines()
x3points = [0]
y3points = [0]
lastind = 1
total = 0
for each in lines:
    point = each.split()
    total+=1
    if int(point[0]) != lastind:
        x3points.append(lastind)
        y3points.append(total)
        lastind = int(point[0])     

print len(x2points)
print len(y2points)
print ypoints[:10]
plt.plot(xpoints,ypoints,label="PCFG")
plt.plot(x2points,y2points,label="personalPCFG",linestyle="--")
#plt.plot(x3points,y3points,label="personalPCFG-guessing")
#plt.xscale('log', nonposy='clip')
#plt.yscale('log', nonposy='clip')
plt.ylabel('Percentage of Cracked Passwords', fontsize=12)
plt.xlabel('Guessing Number', fontsize=14)
plt.legend()
axes = plt.gca()
axes.set_xlim([0,0.14*10**8])

plt.legend(bbox_to_anchor=(1.0, 0.3))
plt.grid()
plt.show()
print ypoints[-1] * 65695
print y2points[-1] * 65695
print xpoints[-1]
# Out:
# 27380
# 27380
# [0, 0.0050079914757591906, 0.006438846183118959, 0.007763147880356191, 0.008387244082502474, 0.008874343557348353, 0.009574549052439303, 0.011553390669000685, 0.011964380850901896, 0.013273460689550194]
# 28164.0
# 30519.0
# 300885724

# %%
# Out:
# 15915

# %%
import pickle
cvglist = pickle.load( open( "cvg.p", "rb" ) )
import numpy as np

#from pylab import rcParams
#rcParams['figure.figsize'] = 10, 5
plt.hist(cvglist,bins=10)
plt.ylabel('Number of Passwords')
plt.xlabel('Coverage')
plt.show()



# Some fake data:
data = cvglist

sorted_data = np.sort(data)  # Or data.sort(), if data can be modified

# Cumulative distributions:
plt.step(sorted_data, np.arange(sorted_data.size)/float(len(cvglist)),label="12306",color="green")  # From 0 to the number of data points-1
plt.ylabel('Cumulative Probability')
plt.xlabel('Coverage')
plt.legend(bbox_to_anchor=(0.3, 1.))
plt.show()

# %%
# Out:
# 13025.0
# 0.0991331085555

# %%
for i in range(0,len(ypoints)):
    if ypoints[i]>0.047:
        print i
        break
# Out:
# 855

# %%
output = open("PCFG_output.txt","r")
lines = output.readlines()
xpoints = [0]
ypoints = [0]
lastind = 1
total = 0
for each in lines:
    point = each.split()
    total+=1
    if int(point[0]) != lastind:
        xpoints.append(lastind)
        ypoints.append(total/65695.0)
        lastind = int(point[0])
output.close()


output = open("output_personal_limit100.txt","r")
lines=output.readlines()
output.close()
x2points=[0]*101
y2points = [0]*101
for each in lines:
    point = each.split()
    total+=1
    x2points[int(point[0])] += 1
for i in range(0,len(y2points)):
    x2points[i] /= 65695.0
    
for i in range(1,101):
    y2points[i] = y2points[i-1]+x2points[i]
plt.plot(xpoints,ypoints,label="PCFG")

plt.plot(y2points,label="Personal-PCFG",ls="--")
#plt.plot(x3points,y3points,label="personalPCFG-guessing")
#plt.xscale('log', nonposy='clip')
#plt.yscale('log', nonposy='clip')
plt.ylabel('Percentage of Cracked Passwords', fontsize=12)
plt.xlabel('Guessing Number', fontsize=14)
plt.legend()
axes = plt.gca()
axes.set_xlim([0,100])
axes.set_ylim([0,0.2])

plt.legend(bbox_to_anchor=(0.42, 1))
plt.grid()
plt.show()

# %%
for atp in (1,3,5,10,50,100):
    print ypoints[atp], ypoints[atp]* 65695
    print y2points[atp],y2points[atp]*65695
lgdif = 0
smdif = 10
for apt in range(1,101):
    diff = (y2points[apt] - ypoints[apt]) / ypoints[apt]
    if diff > lgdif:
        lgdif = diff
    if diff < smdif:
        smdif = diff
print lgdif,smdif
# Out:
# 0.00500799147576 329.0
# 0.0211583834386 1390.0
# 0.00776314788036 510.0
# 0.0367151229165 2412.0
# 0.00887434355735 583.0
# 0.0470203211812 3089.0
# 0.0138214475988 908.0
# 0.0629576071238 4136.0
# 0.0199710784687 1312.0
# 0.132186619986 8684.0
# 0.0231828906309 1523.0
# 0.173559631631 11402.0
# 6.48653972423 3.22492401216

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

## the data
N = 6
menMeans = [0.5, 0.8, 0.9, 1.4, 2.0, 2.3]
womenMeans = [2.1, 3.7, 4.7, 6.3, 13.2,17.4]

## necessary variables
ind = np.arange(N)                # the x locations for the groups
width = 0.35                      # the width of the bars

## the bars
rects1 = ax.bar(ind, menMeans, width,
                color='black')

rects2 = ax.bar(ind+width, womenMeans, width,
                    color='red')

# axes and labels
ax.set_xlim(-width,len(ind)+width)
ax.set_ylim(0,20)
ax.set_ylabel('Percentage of Cracked Passwords', fontsize=12)

xTickMarks = ["1 guess","3 guesses","5 guesses" ,"10 guesses","50 guesses" ,"100 guesses"]

ax.set_xticks(ind+width)
xtickNames = ax.set_xticklabels(xTickMarks)
plt.setp(xtickNames, rotation=45, fontsize=10)
## add a legend
plt.legend((rects1[0], rects2[0]), ('PCFG', 'Personal-PCFG'),bbox_to_anchor=(0.45,1))

plt.show()
